# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("labeled_data.csv")

# %%
dataset
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [24783 rows x 7 columns]

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0            0
# count                 0
# hate_speech           0
# offensive_language    0
# neither               0
# class                 0
# tweet                 0
# dtype: int64

# %%
dataset["labels"] = dataset["class"].map({0: "Offensive Language or Hate Speech",
                                         1: "Offensive Language or Hate Speech",
                                         2: "No hate or offensive Language"})

# %%
data = dataset[["tweet", "labels"]]

# %%
data
# Out:
#                                                    tweet  \
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
#                                   labels
# 0          No hate or offensive Language
# 1      Offensive Language or Hate Speech
# 2      Offensive Language or Hate Speech
# 3      Offensive Language or Hate Speech
# 4      Offensive Language or Hate Speech
# ...                                  ...
# 24778  Offensive Language or Hate Speech
# 24779      No hate or offensive Language
# 24780  Offensive Language or Hate Speech
# 24781  Offensive Language or Hate Speech
# 24782      No hate or offensive Language
#
# [24783 rows x 2 columns]

# %% [markdown]
# import re
# import nltk
# import string

# %%
stopwords = set(nltk.corpus.stopwords.words("english"))

# %%
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
stemmer = nltk.SnowballStemmer("english")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          24783 non-null  int64
#  1   count               24783 non-null  int64
#  2   hate_speech         24783 non-null  int64
#  3   offensive_language  24783 non-null  int64
#  4   neither             24783 non-null  int64
#  5   class               24783 non-null  int64
#  6   tweet               24783 non-null  object
#  7   labels              24783 non-null  object
# dtypes: int64(6), object(2)
# memory usage: 1.5+ MB

# %%
dataset.describe()
# Out:
#          Unnamed: 0         count   hate_speech  offensive_language  \
# count  24783.000000  24783.000000  24783.000000        24783.000000
# mean   12681.192027      3.243473      0.280515            2.413711
# std     7299.553863      0.883060      0.631851            1.399459
# min        0.000000      3.000000      0.000000            0.000000
# 25%     6372.500000      3.000000      0.000000            2.000000
# 50%    12703.000000      3.000000      0.000000            3.000000
# 75%    18995.500000      3.000000      0.000000            3.000000
# max    25296.000000      9.000000      7.000000            9.000000
#
#             neither         class
# count  24783.000000  24783.000000
# mean       0.549247      1.110277
# std        1.113299      0.462089
# min        0.000000      0.000000
# 25%        0.000000      1.000000
# 50%        0.000000      1.000000
# 75%        0.000000      1.000000
# max        9.000000      2.000000

# %%
def data_clean(text):
    text = str(text).lower()
    text = re.sub("hhtps?://S+www\\.S+", "", text)
    text = re.sub("\\[.*?\\]", "", text)
    text = re.sub("<.*?>+", "", text)
    text = re.sub("[%s]" % re.escape(string.punctuation), "", text)
    text = re.sub("\\n", "", text)
    text = re.sub("\\w*\\d\\w*", "", text)
    words = [stemmer.stem(word) for word in text.split() if word not in stopwords]
    text = " ".join(words)
    return text

# %%
data["tweet"] = data["tweet"].apply(data_clean)
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_13892\2274407121.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["tweet"] = data["tweet"].apply(data_clean)

# %%
data
# Out:
#                                                    tweet  \
# 0      rt mayasolov woman shouldnt complain clean hou...
# 1       rt boy dat coldtyga dwn bad cuffin dat hoe place
# 2      rt urkindofbrand dawg rt ever fuck bitch start...
# 3                 rt cganderson vivabas look like tranni
# 4      rt shenikarobert shit hear might true might fa...
# ...                                                  ...
# 24778  yous muthafin lie coreyemanuel right tl trash ...
# 24779  youv gone broke wrong heart babi drove redneck...
# 24780  young buck wanna eat dat nigguh like aint fuck...
# 24781                     youu got wild bitch tellin lie
# 24782  ruffl ntac eileen dahlia beauti color combin p...
#
#                                   labels
# 0          No hate or offensive Language
# 1      Offensive Language or Hate Speech
# 2      Offensive Language or Hate Speech
# 3      Offensive Language or Hate Speech
# 4      Offensive Language or Hate Speech
# ...                                  ...
# 24778  Offensive Language or Hate Speech
# 24779      No hate or offensive Language
# 24780  Offensive Language or Hate Speech
# 24781  Offensive Language or Hate Speech
# 24782      No hate or offensive Language
#
# [24783 rows x 2 columns]

# %%
X = np.array(data["tweet"])
Y = np.array(data["labels"])

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
cv = CountVectorizer()
X = cv.fit_transform(X)

# %%
X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 198289 stored elements and shape (24783, 26152)>

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_depth = 100)
dt.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=100)

# %%
Y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm = confusion_matrix(Y_test, Y_pred)
cm
# Out:
# array([[1094,  135],
#        [ 299, 5907]], dtype=int64)

# %%
print(classification_report(Y_test, Y_pred))
# Out:
#                                    precision    recall  f1-score   support
#
#     No hate or offensive Language       0.79      0.89      0.83      1229
# Offensive Language or Hate Speech       0.98      0.95      0.96      6206
#
#                          accuracy                           0.94      7435
#                         macro avg       0.88      0.92      0.90      7435
#                      weighted avg       0.95      0.94      0.94      7435

# %%
dt.max_depth
# Out:
# 100
